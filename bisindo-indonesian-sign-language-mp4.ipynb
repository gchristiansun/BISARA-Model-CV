# %% [markdown]
# #BISINDO (Bahasa Isyarat Indonesia - I)ndonesian Sign Language)
#
# Indonesian Sign Language, or Bahasa Isyarat Indonesia (BISINDO), is any of several related deaf sign languages of Indonesia, at least on the island of Java. It is based on American Sign Language, with local admixture in different cities. Although presented as a coherent language when advocating for recognition by the Indonesian government and use in education, the varieties used in different cities may not be mutually intelligible.
#
# https://en.wikipedia.org/wiki/Indonesian_Sign_Language

# %% [markdown]
# ![](http://i0.wp.com/ispasier.files.wordpress.com/2016/11/img_20161120_200721.jpg?w=336)ispasier.wordpress.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #By Rob Mulla https://www.kaggle.com/robikscube/kaggle-deepfake-detection-introduction

# %%
#By Rob Mulla https://www.kaggle.com/robikscube/kaggle-deepfake-detection-introduction  

import cv2 as cv
import os
import matplotlib.pylab as plt
train_dir = 'data/alfabet/testing/U/'
fig, ax = plt.subplots(1,1, figsize=(15, 15))
train_video_files = [train_dir + x for x in os.listdir(train_dir)]
# video_file = train_video_files[30]
video_file = 'data/alfabet/testing/U/01.mp4'
cap = cv.VideoCapture(video_file)
success, image = cap.read()
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
cap.release()   
ax.imshow(image)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.title.set_text(f"FRAME 0: {video_file.split('/')[-1]}")
plt.grid(False)

# %% [markdown]
# #Below from Stack Overflow
#
# Error: OpenCV(4.5.1) /tmp/pip-req-build-tk9iuyva/opencv/modules/highgui/src/window.cpp:651: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
#From https://stackoverflow.com/questions/36634807/how-do-i-open-an-mp4-video-file-with-python

import cv2
 
# Create a VideoCapture object and read from input file
# If the input is the camera, pass 0 instead of the video file name
cap = cv2.VideoCapture('data/alfabet/testing/R/01.mp4')
 
 
# Check if camera opened successfully
if (cap.isOpened()== False):
  print("Error opening video stream or file")
 
# Read until video is completed
while (cap.isOpened()):
    # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True:
 
        # Display the resulting frame
        cv2.imshow('Frame', frame)
 
        # Press Q on keyboard to  exit
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break
 
    # Break the loop
    else:
        break
 
# When everything done, release the video capture object
cap.release()
 
# Closes all the frames
cv2.destroyAllWindows()

# %%
# !pip install imageio-ffmpeg
# Out:
# Requirement already satisfied: imageio-ffmpeg in c:\users\gregorius christian\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.6.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: C:\Users\Gregorius Christian\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# #Code by Soham Mukherjee https://www.kaggle.com/soham1024/read-all-kind-of-files-using-python/data

# %%
import pylab
import imageio
filename = 'data/alfabet/testing/K/01.mp4'
vid = imageio.get_reader(filename,  'ffmpeg')
nums = [10, 91]
for num in nums:
    image = vid.get_data(num)
    fig = pylab.figure()
    fig.suptitle('image #{}'.format(num), fontsize=20)
    pylab.imshow(image)
pylab.show()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\imageio\core\format.py:434, in Format.Reader.get_data(self, index, **kwargs)
#     433 try:
# --> 434     im, meta = self._get_data(index, **kwargs)
#     435 except StopIteration:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\imageio\plugins\ffmpeg.py:417, in FfmpegFormat.Reader._get_data(self, index)
#     416     self._skip_frames(index - self._pos - 1)
# --> 417 result, is_new = self._read_frame()
#     418 self._pos = index
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\imageio\plugins\ffmpeg.py:520, in FfmpegFormat.Reader._read_frame(self)
#     519 else:
# --> 520     s = self._read_gen.__next__()
#     521     is_new = True
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 7
#       5 nums = [10, 287]
#       6 for num in nums:
# ----> 7     image = vid.get_data(num)
#       8     fig = pylab.figure()
#       9     fig.suptitle('image #{}'.format(num), fontsize=20)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\imageio\core\format.py:436, in Format.Reader.get_data(self, index, **kwargs)
#     434     im, meta = self._get_data(index, **kwargs)
#     435 except StopIteration:
# --> 436     raise IndexError(index)
#     437 return Array(im, meta)
#
# IndexError: 287

# %%
# !pip install sk-video

# %%
import skvideo.io  
videodata = skvideo.io.vread("data/alfabet/testing/R/01.mp4")  
print(videodata.shape)

# %%
#By Rob Mulla https://www.kaggle.com/robikscube/kaggle-deepfake-detection-introduction  

import cv2 as cv
import os
import matplotlib.pylab as plt
train_dir = 'data/alfabet/testing/H/'
fig, ax = plt.subplots(1,1, figsize=(15, 15))
train_video_files = [train_dir + x for x in os.listdir(train_dir)]
# video_file = train_video_files[30]
video_file = 'data/alfabet/testing/H/01.mp4'
cap = cv.VideoCapture(video_file)
success, image = cap.read()
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
cap.release()   
ax.imshow(image)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.title.set_text(f"FRAME 0: {video_file.split('/')[-1]}")
plt.grid(False)

# %%
#By Rob Mulla https://www.kaggle.com/robikscube/kaggle-deepfake-detection-introduction  

import cv2 as cv
import os
import matplotlib.pylab as plt
train_dir = 'data/alfabet/training/J/'
fig, ax = plt.subplots(1,1, figsize=(15, 15))
train_video_files = [train_dir + x for x in os.listdir(train_dir)]
# video_file = train_video_files[30]
video_file = 'data/alfabet/training/J/02.mp4'
cap = cv.VideoCapture(video_file)
success, image = cap.read()
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
cap.release()   
ax.imshow(image)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.title.set_text(f"FRAME 0: {video_file.split('/')[-1]}")
plt.grid(False)

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#eb3434','#eb3446','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Be patient. That is all kagglers, @mpwolke was Here.' )

# %%
import imageio

filename = 'data/alfabet/testing/K/01.mp4'

vid = imageio.get_reader(filename, 'ffmpeg')

print("Total frame:", vid.count_frames())
# Out:
# Total frame: 91
